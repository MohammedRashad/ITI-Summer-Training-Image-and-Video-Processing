# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/word-image-29.jpeg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1024x700 at 0x7FDCA2771E10>

# %%
blur_img = cv2.GaussianBlur(img,(3,3),0)
cv2_imshow(blur_img)
# Out:
# <PIL.Image.Image image mode=L size=1024x700 at 0x7FDC998A48D0>

# %%
sobelxy = cv2.Sobel(src=blur_img, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5)

cv2_imshow(cv2.convertScaleAbs(sobelxy))
# Out:
# <PIL.Image.Image image mode=L size=1024x700 at 0x7FDC997E0C10>

# %%
edges  = cv2.Canny(image=blur_img, threshold1=100, threshold2=200)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=1024x700 at 0x7FDC99830BD0>

# %%
laplacian = cv2.Laplacian(blur_img,5,cv2.CV_64F)
filtered_image = cv2.convertScaleAbs(laplacian)
cv2_imshow(filtered_image)
# Out:
# <PIL.Image.Image image mode=L size=1024x700 at 0x7FDC99839950>
